# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
# a = 

a = pd.Series([ 100, 200, 300, 400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
print(type(a))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
a[2]
# Out:
# 300

# %% [markdown]
# What are the values of index for series a?

# %%
a.index.values
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ["c","a","b","d"]

a
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Access the value in the series with index 'd'

# %%
a["d"]
# Out:
# 400

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
a.sort_index(inplace =  True)
a
# Out:
# a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
# b = 

b = pd.Series([800, 450, 100], index = ["e", "f", "g"])
print(b)
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
# a =
a = a.append(b)
print(a)
# Out:
# a    200
# b    300
# c    100
# d    400
# e    800
# f    450
# g    100
# dtype: int64
# <ipython-input-12-4b69df4d52c2>:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a = a.append(b)

# %%
#print a again after appending b into it


print(a)
# Out:
# a    200
# b    300
# c    100
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
# a = 
a = a.sort_values(ascending=False)

# %%
print(a)
# Out:
# e    800
# f    450
# d    400
# b    300
# a    200
# c    100
# g    100
# dtype: int64

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
# df = 

df = pd.DataFrame(a)
df.head()
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200

# %%
df
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200
# c  100
# g  100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
df.shape
# Out:
# (7, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
# yep its same as the series.

df.index
# Out:
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
df.head() # This fucton returns the top row of that dataframe default is 5
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200

# %%
df.tail() # This fucton returns the bottom row of that dataframe default is 5
# Out:
#      0
# d  400
# b  300
# a  200
# c  100
# g  100

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df.rename(columns  = {0:"points"}, inplace =True)
df.head()
# Out:
#    points
# e     800
# f     450
# d     400
# b     300
# a     200

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
#Create fruits array

# fruits =

fruits = np.array(["orange","apple","mango", "apple", "mango", "orange", "apple"])
print(fruits)
# Out:
# ['orange' 'apple' 'mango' 'apple' 'mango' 'orange' 'apple']

# %%
#Create series fruits out of fruits array

# fruits =
fruits = pd.Series(fruits)
print(fruits)
# Out:
# 0    orange
# 1     apple
# 2     mango
# 3     apple
# 4     mango
# 5    orange
# 6     apple
# dtype: object

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
df.set_index(fruits, inplace = True)
print(df)
# Out:
#         points
# orange     800
# apple      450
# mango      400
# apple      300
# mango      200
# orange     100
# apple      100

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df.reset_index(inplace =True)
df.rename(columns = {"index":"fruits"}, inplace = True)
df.drop(columns="level_0",  inplace = True)

# %%
df
# Out:
#    fruits  points
# 0  orange     800
# 1   apple     450
# 2   mango     400
# 3   apple     300
# 4   mango     200
# 5  orange     100
# 6   apple     100

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
# d1 = 

d1 = pd.DataFrame({"city":["Chandigarh","Delhi","Kanpur","Chennai","Manali"],
                   "Temperature":[15,22,20,26,-2]})
d1.head()
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
d1.shape
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city = d1["city"]

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)
print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
# d2 = 

d2 = pd.DataFrame({"city":["Bengalaru","Coimbatore","Srirangam","Pondicherry"],
                   "Temperature":[24,35,36,39]})
d2
# Out:
#           city  Temperature
# 0    Bengalaru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# print the shape of this dataframe

# %%
d2.shape
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
# d3 = 

d3 = d1.merge(d2, how = "outer")
d3
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 5    Bengalaru           24
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
d3[d3["Temperature"] <= 20]
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
d3[d3["Temperature"] >= 35]
# Out:
#           city  Temperature
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
# write function here

# def is_ut(x):
    
#     # write code below

def is_ut(x):
  if x in ["Chandigarh", "Pondicherry", "Delhi"]:
    return True
  else:
    return False 
    
# d3['is_ut'] =

d3['is_ut'] = d3["city"].apply(is_ut)

# %%
# print d3
d3
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 5    Bengalaru           24  False
# 6   Coimbatore           35  False
# 7    Srirangam           36  False
# 8  Pondicherry           39   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
# write function here

def c_to_f(x):
  return  (x * (9/5)) + 32

d3
# Out:
#           city  Temperature  is_ut  temp_in_fehr
# 0   Chandigarh           15   True          59.0
# 1        Delhi           22   True          71.6
# 2       Kanpur           20  False          68.0
# 3      Chennai           26  False          78.8
# 4       Manali           -2  False          28.4
# 5    Bengalaru           24  False          75.2
# 6   Coimbatore           35  False          95.0
# 7    Srirangam           36  False          96.8
# 8  Pondicherry           39   True         102.2

# %%
# check function c_to_f(10)
c_to_f(10)
# Out:
# 50.0

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'

d3['temp_farenhiet'] = d3["Temperature"].apply(c_to_f)
d3
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 0   Chandigarh           15   True            59.0
# 1        Delhi           22   True            71.6
# 2       Kanpur           20  False            68.0
# 3      Chennai           26  False            78.8
# 4       Manali           -2  False            28.4
# 5    Bengalaru           24  False            75.2
# 6   Coimbatore           35  False            95.0
# 7    Srirangam           36  False            96.8
# 8  Pondicherry           39   True           102.2

# %%
d3.head()
# Out:
#          city  Temperature  is_ut  temp_farenhiet
# 0  Chandigarh           15   True            59.0
# 1       Delhi           22   True            71.6
# 2      Kanpur           20  False            68.0
# 3     Chennai           26  False            78.8
# 4      Manali           -2  False            28.4

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %%
d1
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
d1["is_ut"] = d1["city"].map(is_ut)
d1[d1["is_ut"] == True]
# Out:
#          city  Temperature  is_ut
# 0  Chandigarh           15   True
# 1       Delhi           22   True

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
d1["temp_fehr"] = d1["Temperature"].map(c_to_f)
d1[d1["temp_fehr"] > 90 ]
# Out:
# Empty DataFrame
# Columns: [city, Temperature, is_ut, temp_fehr]
# Index: []

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
d1.head(3)
# Out:
#          city  Temperature  is_ut  temp_fehr
# 0  Chandigarh           15   True       59.0
# 1       Delhi           22   True       71.6
# 2      Kanpur           20  False       68.0

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
d1.iloc[::,2::]
# Out:
#    is_ut  temp_fehr
# 0   True       59.0
# 1   True       71.6
# 2  False       68.0
# 3  False       78.8
# 4  False       28.4

# %% [markdown]
# ## Groupby

# %%
# Create a dataframe using dictionary of your choice

# data = 
import pandas as pd
data = pd.DataFrame({"name":["suresh","kamlesh","dinesh","somesh","yash"],"age":[20,21,20,23,21],"place":["mp","up","mh","mp","up"]})
data
# Out:
#       name  age place
# 0   suresh   20    mp
# 1  kamlesh   21    up
# 2   dinesh   20    mh
# 3   somesh   23    mp
# 4     yash   21    up

# %%
# Use Groupby of single column with aggregate sum()

data.groupby(["place"])["age"].sum()
# Out:
# place
# mh    20
# mp    43
# up    42
# Name: age, dtype: int64

# %%
# Use Groupby of single column with aggregate count()
data.groupby(["age"])["place"].count()
# Out:
# age
# 20    2
# 21    2
# 23    1
# Name: place, dtype: int64

# %%
# Use Groupby of single column with aggregate min() and max()

print(data.groupby(["place"])["age"].min())
print(data.groupby(["place"])["age"].max())
# Out:
# place
# mh    20
# mp    20
# up    21
# Name: age, dtype: int64
# place
# mh    20
# mp    23
# up    21
# Name: age, dtype: int64

# %%
# Use Groupby of any 2 columns with aggregate mean()

data.groupby(["place","age"]).mean()
# Out:
# <ipython-input-16-90cfbb4a5c07>:3: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   data.groupby(["place","age"]).mean()
# Empty DataFrame
# Columns: []
# Index: [(mh, 20), (mp, 20), (mp, 23), (up, 21)]

# %%
# Use Groupby of any 2 columns with aggregate min() and max()

data.groupby(["place","age"]).min()
data.groupby(["place","age"]).max()
# Out:
#              name
# place age
# mh    20   dinesh
# mp    20   suresh
#       23   somesh
# up    21     yash

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
# a = 
a = pd.date_range(start='1/1/2020', end='1/04/2021')

# %% [markdown]
# print a

# %%
print(a)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31', '2021-01-01', '2021-01-02',
#                '2021-01-03', '2021-01-04'],
#               dtype='datetime64[ns]', length=370, freq='D')

# %% [markdown]
# What is the len of a?

# %%
print(len(a))
# Out:
# 370

# %% [markdown]
# What is the type of a?

# %%
print(type(a))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
